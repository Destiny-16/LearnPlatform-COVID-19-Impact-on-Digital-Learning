# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('districts_info.csv')

# %%
#removing NaN values
df = df.dropna()
df
# Out:
#      district_id           state  locale pct_black/hispanic pct_free/reduced  \
# 0           8815        Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 2           4921            Utah  Suburb           [0, 0.2[       [0.2, 0.4[
# 5           5987       Wisconsin  Suburb           [0, 0.2[         [0, 0.2[
# 6           3710            Utah  Suburb           [0, 0.2[       [0.4, 0.6[
# 7           7177  North Carolina  Suburb         [0.2, 0.4[       [0.2, 0.4[
# ..           ...             ...     ...                ...              ...
# 220         3732        Michigan  Suburb         [0.4, 0.6[       [0.4, 0.6[
# 224         3266            Utah    Town           [0, 0.2[       [0.4, 0.6[
# 227         1705      Washington    City         [0.2, 0.4[       [0.4, 0.6[
# 228         9515        New York   Rural           [0, 0.2[       [0.4, 0.6[
# 230         4929        Virginia   Rural           [0, 0.2[       [0.4, 0.6[
#
#     county_connections_ratio    pp_total_raw
# ...

# %%
#ordering by state
pd.set_option('display.max_rows', None)
df.sort_values('state')
# Out:
#      district_id           state  locale pct_black/hispanic pct_free/reduced  \
# 104         6919         Florida  Suburb         [0.4, 0.6[       [0.4, 0.6[
# 0           8815        Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 169         2285        Illinois  Suburb           [0, 0.2[       [0.4, 0.6[
# 56          9899        Illinois  Suburb         [0.2, 0.4[         [0, 0.2[
# 58          4629        Illinois  Suburb           [0, 0.2[       [0.2, 0.4[
# 34          6577        Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 71          1712        Illinois  Suburb         [0.4, 0.6[       [0.4, 0.6[
# 78          5042        Illinois    Town         [0.2, 0.4[         [0.8, 1[
# 24          9043        Illinois  Suburb           [0.8, 1[         [0.8, 1[
# 54          2601        Illinois  Suburb         [0.6, 0.8[       [0.4, 0.6[
# 20          2779        Illinois   Rural           [0, 0.2[         [0, 0.2[
# ...

# %%
#how many districts for each state
df.groupby('state').state.count()
# Out:
# state
# Florida            1
# Illinois          18
# Indiana            7
# Michigan           2
# Minnesota          1
# Missouri           5
# New Jersey         2
# New York           5
# North Carolina     4
# Texas              2
# Utah              29
# Virginia           3
# Washington         6
# Wisconsin          3
# Name: state, dtype: int64
